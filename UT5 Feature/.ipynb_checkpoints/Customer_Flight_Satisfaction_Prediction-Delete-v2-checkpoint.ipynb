# %% [markdown]
# # Context and Defining Problem Statement
#
# The data we have at hand is of passengers and their feedback regarding their flight experience.
#
# Each row is one passenger. Apart from the  feedback from the customers accross various attributes(15 in total) like food, online_support, cleanliness etc, we have data about the customers' age, loyalty to the airline, gender and class.
#
# The target column is a binary variable which tells us if the customer is satisfied or neutral/dissatisfied
#
# The task at hand is to analyze the data and build a model to predict customer satisfaction using all or some of the data we have.

# %% [markdown]
# # Steps -
# - Data loading and preprocessing
# - Exploratory Data Analysis
# - Model building and evaluation
# - Model Tuning
# - Implementing the process through Pipeline

# %% [markdown]
# # Data loading and preprocessing

# %% [markdown]
# ### 1. Import Pandas, Numpy, pyplot and seaborn

# %%
#Import necessary libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")  # Not always recommended, but jsut so our notebook looks clean for this activity
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### 2. Import the dataframes that are needed
# - Import "Flight data_Train.csv" and "Surveydata_Train.csv"

# %%
df1 = pd.read_csv("Flight_data.csv")  # Read the data regarding customer attributes
df2 = pd.read_csv("Survey_data.csv")   # Feedback data from customers

# %%
df1.shape
# Out:
# (90917, 9)

# %%
df2.shape
# Out:
# (90917, 16)

# %% [markdown]
# ### 3. Join the two dataframes using the 'id' column as the primary key
# - Rename the Id column of one dataframe so that there "id" column name becomes same

# %%
df4 = df2.set_index("4")
df3 = df1.set_index("3")
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-dbd698451672> in <module>
# ----> 1 df4 = df2.set_index("4")
#       2 df3 = df1.set_index("3")
#       3 df4
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4548
#    4549         if missing:
# -> 4550             raise KeyError(f"None of {missing} are in the columns")
#    4551
#    4552         if inplace:
#
# KeyError: "None of ['4'] are in the columns"

# %%
#Using pandas' Join method
#c = a.join(b)  # Joining two dfs on the 'Id' column

df = df2.set_index("Id").join(df1.set_index("ID"))


print(df.shape)
df.head()  # the combined dataframe
# Out:
# (90917, 23)
#                    Satisfaction Seat_comfort  \
# Id
# 198671  neutral or dissatisfied         poor
# 193378                satisfied    excellent
# 174522                satisfied         good
# 191830                satisfied         good
# 221497                satisfied         good
#
#        Departure.Arrival.time_convenient  Food_drink Gate_location  \
# Id
# 198671                        acceptable  acceptable    manageable
# 193378                  need improvement   excellent    Convinient
# 174522                              good        good    manageable
# 191830                              good        good    manageable
# 221497                              good         NaN    Convinient
#
#        Inflightwifi_service Inflight_entertainment Online_support  \
# Id
# 198671                 poor       need improvement           poor
# 193378           acceptable              excellent     acceptable
# 174522           acceptable              excellent      excellent
# 191830                 poor                   good           poor
# 221497                 good                   good           good
#
#        Ease_of_Onlinebooking   Onboard_service  ...       Cleanliness  \
# Id                                              ...
# 198671                  poor        acceptable  ...  need improvement
# 193378            acceptable              good  ...         excellent
# 174522      need improvement  need improvement  ...  need improvement
# 191830                  poor              poor  ...        acceptable
# 221497                  good              good  ...              good
#
#        Online_boarding  Gender       CustomerType Age       TypeTravel  \
# Id
# 198671            poor    Male     Loyal Customer  30  Business travel
# 193378      acceptable  Female  disloyal Customer  20              NaN
# 174522       excellent  Female                NaN  55  Personal Travel
# 191830            poor    Male  disloyal Customer  24  Business travel
# 221497            good    Male     Loyal Customer  32  Business travel
#
#            Class  Flight_Distance DepartureDelayin_Mins ArrivalDelayin_Mins
# Id
# 198671  Business             1354                    11                 8.0
# 193378  Business             1439                     6                 0.0
# 174522  Eco Plus              976                     4                 0.0
# 191830       Eco             2291                     0                 0.0
# 221497  Business             3974                     0                 0.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 4. Print the number of missing values in each of the columns

# %%
df.isna().sum() # Since True is 1 and False is 0, if you do a sum of a boolean dataframe, we get the number of trues in each col
# Out:
# Satisfaction                            0
# Seat_comfort                            0
# Departure.Arrival.time_convenient    8244
# Food_drink                           8181
# Gate_location                           0
# Inflightwifi_service                    0
# Inflight_entertainment                  0
# Online_support                          0
# Ease_of_Onlinebooking                   0
# Onboard_service                      7179
# Leg_room_service                        0
# Baggage_handling                        0
# Checkin_service                         0
# Cleanliness                             0
# Online_boarding                         0
# Gender                                  0
# CustomerType                         9099
# Age                                     0
# TypeTravel                           9088
# Class                                   0
# Flight_Distance                         0
# DepartureDelayin_Mins                   0
# ArrivalDelayin_Mins                   284
# dtype: int64

# %%
# you can also find it using the snippet below
df.isnull().apply(pd.value_counts).fillna(0)
# Out:
#        Satisfaction  Seat_comfort  Departure.Arrival.time_convenient  \
# False       90917.0       90917.0                              82673
# True            0.0           0.0                               8244
#
#        Food_drink  Gate_location  Inflightwifi_service  \
# False       82736        90917.0               90917.0
# True         8181            0.0                   0.0
#
#        Inflight_entertainment  Online_support  Ease_of_Onlinebooking  \
# False                 90917.0         90917.0                90917.0
# True                      0.0             0.0                    0.0
#
#        Onboard_service  ...  Cleanliness  Online_boarding   Gender  \
# False            83738  ...      90917.0          90917.0  90917.0
# True              7179  ...          0.0              0.0      0.0
#
#        CustomerType      Age  TypeTravel    Class  Flight_Distance  \
# False         81818  90917.0       81829  90917.0          90917.0
# True           9099      0.0        9088      0.0              0.0
#
#        DepartureDelayin_Mins  ArrivalDelayin_Mins
# False                90917.0                90633
# True                     0.0                  284
#
# [2 rows x 23 columns]

# %% [markdown]
# ### 5. Drop all the rows having atleast one missing values and check the shape of the dataframe before and after dropping the rows
# - Fill null values in ArrivalDelayin_Mins with mean
# - After that drop all the rows with null values

# %%
# There are a few columns where out of the total ~90k records, ~8k have missing value. Imputing them with a central tendency
# might add undesirable noise in the data. Hence, lets tackle only the columns that have less missing values.

# But before imputation let us check the distribution of the data. If there are outliers, we would prefer to impute with median
# else mean can be good option.

# %%
sns.boxplot(df['ArrivalDelayin_Mins'])
# Out:
# <AxesSubplot:xlabel='ArrivalDelayin_Mins'>

# %%
df.describe().T
# Out:
#                          count         mean          std   min     25%  \
# Age                    90917.0    39.447166    15.129794   7.0    27.0
# Flight_Distance        90917.0  1981.629442  1026.779932  50.0  1360.0
# DepartureDelayin_Mins  90917.0    14.686593    38.669260   0.0     0.0
# ArrivalDelayin_Mins    90633.0    15.058930    39.038523   0.0     0.0
#
#                           50%     75%     max
# Age                      40.0    51.0    85.0
# Flight_Distance        1927.0  2542.0  6950.0
# DepartureDelayin_Mins     0.0    12.0  1592.0
# ArrivalDelayin_Mins       0.0    13.0  1584.0

# %%
# the above two analysis suggest that we are in for many outliers
# so let us use the median to impute the values
#df.ArrivalDelayin_Mins.fillna(df.ArrivalDelayin_Mins.median(), inplace = True)

# Alternate way - You can use the simpleimputer function of the sklearn.impute. You can try it out!
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'median') 
df['ArrivalDelayin_Mins'] = imputer.fit_transform(df['ArrivalDelayin_Mins'].values.reshape(-1,1))

# Check
df.isna().sum()
# Out:
# Satisfaction                            0
# Seat_comfort                            0
# Departure.Arrival.time_convenient    8244
# Food_drink                           8181
# Gate_location                           0
# Inflightwifi_service                    0
# Inflight_entertainment                  0
# Online_support                          0
# Ease_of_Onlinebooking                   0
# Onboard_service                      7179
# Leg_room_service                        0
# Baggage_handling                        0
# Checkin_service                         0
# Cleanliness                             0
# Online_boarding                         0
# Gender                                  0
# CustomerType                         9099
# Age                                     0
# TypeTravel                           9088
# Class                                   0
# Flight_Distance                         0
# DepartureDelayin_Mins                   0
# ArrivalDelayin_Mins                     0
# dtype: int64

# %%
# Rest other missing values are filled with not_captured.
#It can be done in other way also or also can be dropped according to the problem and business context.
df.dropna(inplace = True)
df.shape
# Out:
# (53798, 23)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 6. Print correlation

# %%
cor = df.corr() # It will show correlation of only numerical variables here.

# %%
cor

# %% [markdown]
# - There is just one obvious correlation that we can see that is between arrival delay and departure delay. We can drop one of the variables here

# %%
to_drop = ['DepartureDelayin_Mins']

# %% [markdown]
# ### Feedback columns
# Seat_comfort', 'Departure.Arrival.time_convenient', 'Food_drink', 'Gate_location',
# 'Inflightwifi_service', 'Inflight_entertainment', 'Online_support',
# 'Ease_of_Onlinebooking', 'Onboard_service', 'Leg_room_service',
# 'Baggage_handling', 'Checkin_service', 'Cleanliness', 'Online_boarding'

# %% [markdown]
# ### 7. Manually encode these variables(printed above) such that they follow an order based on the meaning.

# %%
# Manual label encoding
df.replace({'extremely poor' : 0, 'poor' : 1, 'need improvement' : 2, 'acceptable' : 3, 
            'good' : 4, 'excellent' : 5}, inplace = True)  

df.replace({'very inconvinient' : 0, 'Inconvinient' : 1, 'need improvement' : 2, 'manageable' : 3,
            'Convinient' : 4, 'very convinient' : 5}, inplace = True)

# %%
# check for encodings
df['Departure.Arrival.time_convenient'].value_counts()
# Out:
# 4    12166
# 5    11123
# 3     9656
# 2     9554
# 1     8559
# 0     2740
# Name: Departure.Arrival.time_convenient, dtype: int64

# %% [markdown]
# ### 8. Display countplot of every feedback attribute with respect to Customer Satisfaction.
#
# You can use sns.countplot and set hue  = 'Satisfaction'

# %%
# We can use seaborn's countplot to plot a stacked baatchart
sns.countplot(df.Seat_comfort, hue = df.Satisfaction) 
plt.legend(loc = 'upper right', bbox_to_anchor=(1.45, 1))   # to place the legend in a 'good' position

# %%
# Since there are a lot of columns that we want to plot, we can put all of them 
# in one plot by using subplot() Additionally, since there are a lot of subplots 
# that need to be plotted, we can use a for loop

plt.figure(figsize= (30,18))  # setting the figure size
pos = 1  # we will use this variable to index each of the plots
feedback = [ 'Seat_comfort', 'Departure.Arrival.time_convenient', 'Food_drink',
           'Gate_location', 'Inflightwifi_service','Inflight_entertainment',
           'Online_support', 'Ease_of_Onlinebooking', 'Onboard_service',
           'Leg_room_service', 'Baggage_handling','Checkin_service', 
            'Cleanliness', 'Online_boarding']

for i in feedback:
    plt.subplot(3, 5, pos)
    sns.countplot(df[i], hue = df.Satisfaction,
                  palette = {'satisfied':'green','neutral or dissatisfied': 'red'})
    plt.legend().remove()  # Remove legend to make the entire plot look 'good'
    pos += 1  # to plot over the grid one by one

# %%
# Alternate way
# Using sns.barplot()

plt.figure(figsize= (30,18))  
pos = 2  

for i in feedback:
    ct = pd.crosstab(df[i], df.Satisfaction)  # Crosstab 
    stacked =ct.stack().reset_index().rename(columns={0:'value'}) #dataframe with name and count accross satisfaction levels
    plt.subplot(3, 5, pos)
    sns.barplot(x=stacked[i], y=stacked.value, hue=stacked.Satisfaction,
               palette = {'satisfied':'lightgreen','neutral or dissatisfied': 'coral'}) # Barplot
    plt.legend().remove()  # Remove legend to make the entire plot look 'good'
    pos += 1  # to plot over the grid one by one

# %% [markdown]
# ### 9. Draw all the insights that you can from the plots

# %% [markdown]
# **Green and orange bars are counts of satisfied and dissatisfied customers respectively. We want to look for areas where there is a visually significant difference between the length of the stacked bars**
#
# - From the plots above,
#     - Seating comfort can cause high levels of satisfaction to customers. Hardly any people who rated highly for seat_comfort were dissatisfied
#     - A similar case with respect to inflight_entertainment. In this case, having less entertainment seems to have caused far more dissatisfaction compared to bad seating.
#     - Difference is observed in ease_of_online_booking quiet evidently

# %% [markdown]
# ### 10. Print the average feedback score
# - When Satisfaction columns equals 'satisfied'
# - When Satisfaction columns is not equal to 'satisfied'

# %%
Feedback_cols = ['Seat_comfort', 'Departure.Arrival.time_convenient',
                 'Food_drink', 'Gate_location', 'Inflightwifi_service',
                 'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking', 
                 'Onboard_service', 'Leg_room_service', 'Baggage_handling', 'Checkin_service',
                 'Cleanliness', 'Online_boarding']

# %%
df.groupby('Satisfaction').mean() # Average rating of individual feedback attributes across satisfaction levels
# Out:
#                          Seat_comfort  Departure.Arrival.time_convenient  \
# Satisfaction
# neutral or dissatisfied      2.469468                           3.015667
# satisfied                    3.142271                           2.970793
#
#                          Food_drink  Gate_location  Inflightwifi_service  \
# Satisfaction
# neutral or dissatisfied    2.659690       3.000864              2.922571
# satisfied                  3.001153       2.977238              3.530004
#
#                          Inflight_entertainment  Online_support  \
# Satisfaction
# neutral or dissatisfied                 2.61820        2.963691
# satisfied                               4.01557        3.983751
#
#                          Ease_of_Onlinebooking  Onboard_service  \
# Satisfaction
# neutral or dissatisfied               2.855216         2.972573
# satisfied                             3.996981         3.875912
#
#                          Leg_room_service  Baggage_handling  Checkin_service  \
# Satisfaction
# neutral or dissatisfied          3.061598          3.370040         2.971504
# satisfied                        3.852641          3.972896         3.641100
#
#                          Cleanliness  Online_boarding        Age  \
# Satisfaction
# neutral or dissatisfied     3.380484         2.875529  37.451334
# satisfied                   3.985651         3.750161  41.018590
#
#                          Flight_Distance  DepartureDelayin_Mins  \
# Satisfaction
# neutral or dissatisfied      2028.216251              18.005181
# satisfied                    1943.874894              12.120052
#
#                          ArrivalDelayin_Mins
# Satisfaction
# neutral or dissatisfied            18.609461
# satisfied                          12.286210

# %% [markdown]
# ### 11. Draw any insights that you can from the above values

# %% [markdown]
# - Observe the Exreme values (lower side for 'dissatisfaction' and higher side for 'satisfaction')
# - Bad seats are a strong cause for customer dissatisfication
# - Time convenience doesn't seem to be that big of a deal
# - Dissatisfied customers had some bad experiences with food but average food seems to satisfy most people
# - Gate location is totally irrelevant
# - Wifi is quiet a factor. On an average, having good wifi yeilded customer satisfaction
# - Easy online booking facility seems to be very important for customer satisfaction
# - In flight entertainment seems to be a deal breaker

# %% [markdown]
# ### 12. Create a new column which is the mean of 'Ease_of_Onlinebooking', 'Online_boarding', 'Online_support' and name it "avg_feedback_of_online_services".
#
# DIY : If online services has a bad ratings then what is the average ratings of other feedback attributes?
# And how does it impact Final Satisfaction of customers?

# %%
online_df = df.loc[:, ['Ease_of_Onlinebooking', 'Online_boarding', 'Online_support']]
online_df['avg_feedback_of_online_services'] = online_df.mean(axis = 1)
online_df #['avg_feedback_of_online_services'].value_counts()
# Out:
#         Ease_of_Onlinebooking  Online_boarding  Online_support  \
# Id
# 198671                      1                1               1
# 191830                      1                1               1
# 228137                      4                3               5
# 240081                      4                5               5
# 233692                      5                3               5
# ...                       ...              ...             ...
# 240287                      5                4               5
# 177814                      4                3               4
# 181405                      3                3               3
# 224128                      4                4               4
# 186039                      4                4               4
#
#         avg_feedback_of_online_services
# Id
# 198671                         1.000000
# 191830                         1.000000
# 228137                         4.000000
# 240081                         4.666667
# 233692                         4.333333
# ...                                 ...
# 240287                         4.666667
# 177814                         3.666667
# 181405                         3.000000
# 224128                         4.000000
# 186039                         4.000000
#
# [53798 rows x 4 columns]

# %% [markdown]
# # Model building and evaluation

# %% [markdown]
# ### 14. Encode the columns "Gender", "CustomerType", "TypeTravel", "Class", "Satisfaction"
# - Use manual encoding or other type of encoding

# %%
df.dtypes
# Out:
# Satisfaction                          object
# Seat_comfort                           int64
# Departure.Arrival.time_convenient      int64
# Food_drink                             int64
# Gate_location                          int64
# Inflightwifi_service                   int64
# Inflight_entertainment                 int64
# Online_support                         int64
# Ease_of_Onlinebooking                  int64
# Onboard_service                        int64
# Leg_room_service                       int64
# Baggage_handling                       int64
# Checkin_service                        int64
# Cleanliness                            int64
# Online_boarding                        int64
# Gender                                object
# CustomerType                          object
# Age                                    int64
# TypeTravel                            object
# Class                                 object
# Flight_Distance                        int64
# DepartureDelayin_Mins                  int64
# ArrivalDelayin_Mins                  float64
# dtype: object

# %%
# Number of classes in each of the categorical attributes
for i in df.columns:
    if df[i].dtype == 'O':
        print("---")
        print(i, '->', len(df[i].value_counts()))
        print(df[i].value_counts())
# Out:
# ---
# Satisfaction -> 2
# satisfied                  29479
# neutral or dissatisfied    24319
# Name: Satisfaction, dtype: int64
# ---
# Gender -> 2
# Female    27447
# Male      26351
# Name: Gender, dtype: int64
# ---
# CustomerType -> 2
# Loyal Customer       44031
# disloyal Customer     9767
# Name: CustomerType, dtype: int64
# ---
# TypeTravel -> 2
# Business travel    37084
# Personal Travel    16714
# Name: TypeTravel, dtype: int64
# ---
# Class -> 3
# Business    25718
# Eco         24156
# Eco Plus     3924
# Name: Class, dtype: int64

# %%
#Manuanl Encoding
df.replace({'Loyal Customer' : 1, 'disloyal Customer' : 0,
            'Business travel' : 1, 'Personal Travel' : 0,
            'Female' : 0, 'Male' : 1,
            'satisfied' : 1, 'neutral or dissatisfied' : 0, 
            'Eco Plus': 0 , 'Eco': 1, 'Business': 2}, inplace = True)

# %%
#onehotencoding
df_coded = pd.get_dummies(df)

# %%
df_coded.columns
# Out:
# Index(['Satisfaction', 'Seat_comfort', 'Departure.Arrival.time_convenient',
#        'Food_drink', 'Gate_location', 'Inflightwifi_service',
#        'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding', 'Gender',
#        'CustomerType', 'Age', 'TypeTravel', 'Class', 'Flight_Distance',
#        'DepartureDelayin_Mins', 'ArrivalDelayin_Mins'],
#       dtype='object')

# %%
df_coded.head()
# Out:
#         Satisfaction  Seat_comfort  Departure.Arrival.time_convenient  \
# Id
# 198671             0             1                                  3
# 191830             1             4                                  4
# 228137             1             5                                  5
# 240081             1             1                                  1
# 233692             1             1                                  1
#
#         Food_drink  Gate_location  Inflightwifi_service  \
# Id
# 198671           3              3                     1
# 191830           4              3                     1
# 228137           5              5                     3
# 240081           1              1                     5
# 233692           1              1                     2
#
#         Inflight_entertainment  Online_support  Ease_of_Onlinebooking  \
# Id
# 198671                       2               1                      1
# 191830                       4               1                      1
# 228137                       5               5                      4
# 240081                       5               5                      4
# 233692                       5               5                      5
#
#         Onboard_service  ...  Cleanliness  Online_boarding  Gender  \
# Id                       ...
# 198671                3  ...            2                1       1
# 191830                1  ...            3                1       1
# 228137                4  ...            4                3       1
# 240081                2  ...            3                5       0
# 233692                5  ...            5                3       1
#
#         CustomerType  Age  TypeTravel  Class  Flight_Distance  \
# Id
# 198671             1   30           1      2             1354
# 191830             0   24           1      1             2291
# 228137             1   47           1      2              657
# 240081             1   30           1      2             5342
# 233692             1   58           1      2              351
#
#         DepartureDelayin_Mins  ArrivalDelayin_Mins
# Id
# 198671                     11                  8.0
# 191830                      0                  0.0
# 228137                      0                  0.0
# 240081                    140                125.0
# 233692                      0                  0.0
#
# [5 rows x 23 columns]

# %%
df.describe().T
# Out:
#                                      count         mean          std   min  \
# Satisfaction                       53798.0     0.547957     0.497699   0.0
# Seat_comfort                       53798.0     2.838135     1.394441   0.0
# Departure.Arrival.time_convenient  53798.0     2.991078     1.524952   0.0
# Food_drink                         53798.0     2.846797     1.443158   0.0
# Gate_location                      53798.0     2.987918     1.305901   0.0
# Inflightwifi_service               53798.0     3.255418     1.320235   0.0
# Inflight_entertainment             53798.0     3.383899     1.340946   0.0
# Online_support                     53798.0     3.522640     1.307606   1.0
# Ease_of_Onlinebooking              53798.0     3.480854     1.305044   0.0
# Onboard_service                    53798.0     3.467564     1.270305   0.0
# Leg_room_service                   53798.0     3.495056     1.290595   0.0
# Baggage_handling                   53798.0     3.700379     1.152413   1.0
# Checkin_service                    53798.0     3.338414     1.259607   1.0
# Cleanliness                        53798.0     3.712090     1.145766   0.0
# Online_boarding                    53798.0     3.354790     1.298327   0.0
# Gender                             53798.0     0.489814     0.499901   0.0
# CustomerType                       53798.0     0.818451     0.385476   0.0
# Age                                53798.0    39.406037    15.085411   7.0
# TypeTravel                         53798.0     0.689319     0.462777   0.0
# Class                              53798.0     1.405108     0.621998   0.0
# Flight_Distance                    53798.0  1982.000799  1027.906508  50.0
# DepartureDelayin_Mins              53798.0    14.780382    38.784908   0.0
# ArrivalDelayin_Mins                53798.0    15.144590    39.116573   0.0
#
#                                       25%     50%     75%     max
# Satisfaction                          0.0     1.0     1.0     1.0
# Seat_comfort                          2.0     3.0     4.0     5.0
# Departure.Arrival.time_convenient     2.0     3.0     4.0     5.0
# Food_drink                            2.0     3.0     4.0     5.0
# Gate_location                         2.0     3.0     4.0     5.0
# Inflightwifi_service                  2.0     3.0     4.0     5.0
# Inflight_entertainment                2.0     4.0     4.0     5.0
# Online_support                        3.0     4.0     5.0     5.0
# Ease_of_Onlinebooking                 2.0     4.0     5.0     5.0
# Onboard_service                       3.0     4.0     4.0     5.0
# Leg_room_service                      2.0     4.0     5.0     5.0
# Baggage_handling                      3.0     4.0     5.0     5.0
# Checkin_service                       3.0     3.0     4.0     5.0
# Cleanliness                           3.0     4.0     5.0     5.0
# Online_boarding                       2.0     4.0     4.0     5.0
# Gender                                0.0     0.0     1.0     1.0
# CustomerType                          1.0     1.0     1.0     1.0
# Age                                  27.0    40.0    51.0    85.0
# TypeTravel                            0.0     1.0     1.0     1.0
# Class                                 1.0     1.0     2.0     2.0
# Flight_Distance                    1359.0  1927.5  2540.0  6950.0
# DepartureDelayin_Mins                 0.0     0.0    12.0  1128.0
# ArrivalDelayin_Mins                   0.0     0.0    13.0  1115.0

# %% [markdown]
# # Scaling

# %% [raw]
# #MinMax Scaling - scales the data set such that values are in the range [0, 1].
# #StandardScaler - shift mean to zero and scales the data to unit variance
#
# You can learn about other scalers here -
# https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html

# %%
df_coded.columns
# Out:
# Index(['Satisfaction', 'Seat_comfort', 'Departure.Arrival.time_convenient',
#        'Food_drink', 'Gate_location', 'Inflightwifi_service',
#        'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding', 'Gender',
#        'CustomerType', 'Age', 'TypeTravel', 'Class', 'Flight_Distance',
#        'DepartureDelayin_Mins', 'ArrivalDelayin_Mins'],
#       dtype='object')

# %%
#Here we are going to use StandardScaler to scale our data.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#What all columns to scale? I have preferred all columns except onehotencoded columns 
# and target columns as scaling of target feature will not change anything as they 
# already have values like 0 and 1 only. You may only scale numerical features and 
# leave categorical features as required according to business problem need and results.

cols_to_scale = ['Seat_comfort', 'Departure.Arrival.time_convenient',
       'Food_drink', 'Gate_location', 'Inflightwifi_service',
       'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
       'Onboard_service', 'Leg_room_service', 'Baggage_handling',
       'Checkin_service', 'Cleanliness', 'Online_boarding',
       'Age', 'Flight_Distance','DepartureDelayin_Mins', 'ArrivalDelayin_Mins']

# df_coded[cols_to_scale] = scaler.fit_transform(df_coded[cols_to_scale].to_numpy())
df_coded[cols_to_scale] = scaler.fit_transform(df_coded[cols_to_scale])

# %%
df_coded.head()
# Out:
#         Satisfaction  Seat_comfort  Departure.Arrival.time_convenient  \
# Id
# 198671             0     -1.318200                           0.005851
# 191830             1      0.833219                           0.661615
# 228137             1      1.550359                           1.317380
# 240081             1     -1.318200                          -1.305678
# 233692             1     -1.318200                          -1.305678
#
#         Food_drink  Gate_location  Inflightwifi_service  \
# Id
# 198671    0.106159       0.009252             -1.708362
# 191830    0.799090       0.009252             -1.708362
# 228137    1.492021       1.540776             -0.193466
# 240081   -1.279703      -1.522272              1.321430
# 233692   -1.279703      -1.522272             -0.950914
#
#         Inflight_entertainment  Online_support  Ease_of_Onlinebooking  \
# Id
# 198671               -1.032041       -1.929223              -1.900992
# 191830                0.459457       -1.929223              -1.900992
# 228137                1.205206        1.129831               0.397803
# 240081                1.205206        1.129831               0.397803
# 233692                1.205206        1.129831               1.164068
#
#         Onboard_service  ...  Cleanliness  Online_boarding  Gender  \
# Id                       ...
# 198671        -0.368075  ...    -1.494290        -1.813728       1
# 191830        -1.942515  ...    -0.621503        -1.813728       1
# 228137         0.419144  ...     0.251284        -0.273270       1
# 240081        -1.155295  ...    -0.621503         1.267188       0
# 233692         1.206364  ...     1.124071        -0.273270       1
#
#         CustomerType       Age  TypeTravel  Class  Flight_Distance  \
# Id
# 198671             1 -0.623525           1      2        -0.610957
# 191830             0 -1.021264           1      1         0.300613
# 228137             1  0.503402           1      2        -1.289040
# 240081             1 -0.623525           1      2         3.268809
# 233692             1  1.232591           1      2        -1.586736
#
#         DepartureDelayin_Mins  ArrivalDelayin_Mins
# Id
# 198671              -0.097471            -0.182650
# 191830              -0.381089            -0.387169
# 228137              -0.381089            -0.387169
# 240081               3.228596             2.808437
# 233692              -0.381089            -0.387169
#
# [5 rows x 23 columns]

# %%
df_coded.describe().T
# Out:
#                                      count          mean       std       min  \
# Satisfaction                       53798.0  5.479572e-01  0.497699  0.000000
# Seat_comfort                       53798.0  1.606942e-16  1.000009 -2.035339
# Departure.Arrival.time_convenient  53798.0 -1.490251e-16  1.000009 -1.961443
# Food_drink                         53798.0  2.141572e-16  1.000009 -1.972635
# Gate_location                      53798.0  9.701099e-17  1.000009 -2.288034
# Inflightwifi_service               53798.0  2.189821e-16  1.000009 -2.465810
# Inflight_entertainment             53798.0  3.518681e-16  1.000009 -2.523540
# Online_support                     53798.0 -4.658467e-16  1.000009 -1.929223
# Ease_of_Onlinebooking              53798.0 -5.333437e-16  1.000009 -2.667257
# Onboard_service                    53798.0  4.363710e-16  1.000009 -2.729734
# Leg_room_service                   53798.0  1.299298e-17  1.000009 -2.708122
# Baggage_handling                   53798.0  7.462503e-17  1.000009 -2.343261
# Checkin_service                    53798.0 -9.497093e-18  1.000009 -1.856481
# Cleanliness                        53798.0 -2.303035e-16  1.000009 -3.239864
# Online_boarding                    53798.0  5.222576e-17  1.000009 -2.583956
# Gender                             53798.0  4.898137e-01  0.499901  0.000000
# CustomerType                       53798.0  8.184505e-01  0.385476  0.000000
# Age                                53798.0  1.225831e-18  1.000009 -2.148191
# TypeTravel                         53798.0  6.893193e-01  0.462777  0.000000
# Class                              53798.0  1.405108e+00  0.621998  0.000000
# Flight_Distance                    53798.0  1.782923e-17  1.000009 -1.879567
# DepartureDelayin_Mins              53798.0  6.200083e-16  1.000009 -0.381089
# ArrivalDelayin_Mins                53798.0  2.361850e-16  1.000009 -0.387169
#
#                                         25%       50%       75%        max
# Satisfaction                       0.000000  1.000000  1.000000   1.000000
# Seat_comfort                      -0.601060  0.116080  0.833219   1.550359
# Departure.Arrival.time_convenient -0.649914  0.005851  0.661615   1.317380
# Food_drink                        -0.586772  0.106159  0.799090   1.492021
# Gate_location                     -0.756510  0.009252  0.775014   1.540776
# Inflightwifi_service              -0.950914 -0.193466  0.563982   1.321430
# Inflight_entertainment            -1.032041  0.459457  0.459457   1.205206
# Online_support                    -0.399696  0.365067  1.129831   1.129831
# Ease_of_Onlinebooking             -1.134727  0.397803  1.164068   1.164068
# Onboard_service                   -0.368075  0.419144  0.419144   1.206364
# Leg_room_service                  -1.158434  0.391253  1.166097   1.166097
# Baggage_handling                  -0.607756  0.259997  1.127749   1.127749
# Checkin_service                   -0.268669 -0.268669  0.525237   1.319143
# Cleanliness                       -0.621503  0.251284  1.124071   1.124071
# Online_boarding                   -1.043499  0.496959  0.496959   1.267188
# Gender                             0.000000  0.000000  1.000000   1.000000
# CustomerType                       1.000000  1.000000  1.000000   1.000000
# Age                               -0.822394  0.039374  0.768562   3.022416
# TypeTravel                         0.000000  1.000000  1.000000   1.000000
# Class                              1.000000  1.000000  2.000000   2.000000
# Flight_Distance                   -0.606093 -0.053022  0.542855   4.833169
# DepartureDelayin_Mins             -0.381089 -0.381089 -0.071688  28.702658
# ArrivalDelayin_Mins               -0.387169 -0.387169 -0.054826  28.117638

# %%
df_coded.head()
# Out:
#         Satisfaction  Seat_comfort  Departure.Arrival.time_convenient  \
# Id
# 198671             0     -1.318200                           0.005851
# 191830             1      0.833219                           0.661615
# 228137             1      1.550359                           1.317380
# 240081             1     -1.318200                          -1.305678
# 233692             1     -1.318200                          -1.305678
#
#         Food_drink  Gate_location  Inflightwifi_service  \
# Id
# 198671    0.106159       0.009252             -1.708362
# 191830    0.799090       0.009252             -1.708362
# 228137    1.492021       1.540776             -0.193466
# 240081   -1.279703      -1.522272              1.321430
# 233692   -1.279703      -1.522272             -0.950914
#
#         Inflight_entertainment  Online_support  Ease_of_Onlinebooking  \
# Id
# 198671               -1.032041       -1.929223              -1.900992
# 191830                0.459457       -1.929223              -1.900992
# 228137                1.205206        1.129831               0.397803
# 240081                1.205206        1.129831               0.397803
# 233692                1.205206        1.129831               1.164068
#
#         Onboard_service  ...  Cleanliness  Online_boarding  Gender  \
# Id                       ...
# 198671        -0.368075  ...    -1.494290        -1.813728       1
# 191830        -1.942515  ...    -0.621503        -1.813728       1
# 228137         0.419144  ...     0.251284        -0.273270       1
# 240081        -1.155295  ...    -0.621503         1.267188       0
# 233692         1.206364  ...     1.124071        -0.273270       1
#
#         CustomerType       Age  TypeTravel  Class  Flight_Distance  \
# Id
# 198671             1 -0.623525           1      2        -0.610957
# 191830             0 -1.021264           1      1         0.300613
# 228137             1  0.503402           1      2        -1.289040
# 240081             1 -0.623525           1      2         3.268809
# 233692             1  1.232591           1      2        -1.586736
#
#         DepartureDelayin_Mins  ArrivalDelayin_Mins
# Id
# 198671              -0.097471            -0.182650
# 191830              -0.381089            -0.387169
# 228137              -0.381089            -0.387169
# 240081               3.228596             2.808437
# 233692              -0.381089            -0.387169
#
# [5 rows x 23 columns]

# %%
df = df_coded

# %% [markdown]
# ### 15. Seperate the column "Satisfaction" from the rest of the columns
# - Create X and y

# %%
# We are going to drop highly correlated feature which we have 
# found before as there features might affect our models - to_drop

# %%
# Seperating the target and the rest X = df.drop(columns= ['Satisfaction'])
X = df.drop(columns= ['Satisfaction', 'DepartureDelayin_Mins'])  
y = df.Satisfaction

# %% [markdown]
# ### 16. Create train and test datasets
# - Use train_test_split

# %%
# Splitting the data for training and testing out model

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 1, stratify = y)

# %%
100*y_train.value_counts(normalize=True)
# Out:
# 1    54.795777
# 0    45.204223
# Name: Satisfaction, dtype: float64

# %%
100*y_test.value_counts(normalize=True)
# Out:
# 1    54.795539
# 0    45.204461
# Name: Satisfaction, dtype: float64

# %%
X_train.dtypes
# Out:
# Seat_comfort                         float64
# Departure.Arrival.time_convenient    float64
# Food_drink                           float64
# Gate_location                        float64
# Inflightwifi_service                 float64
# Inflight_entertainment               float64
# Online_support                       float64
# Ease_of_Onlinebooking                float64
# Onboard_service                      float64
# Leg_room_service                     float64
# Baggage_handling                     float64
# Checkin_service                      float64
# Cleanliness                          float64
# Online_boarding                      float64
# Gender                                 int64
# CustomerType                           int64
# Age                                  float64
# TypeTravel                             int64
# Class                                  int64
# Flight_Distance                      float64
# ArrivalDelayin_Mins                  float64
# dtype: object

# %% [markdown]
# ### 17. Print accuracy
# - Print accuracy on test data using below models
# - Logistic regression model trained using all the attributes
# - Logistic regression model trained using only the feedback columns
# - Decision tree model trained using all the attributes
# - Random forest model trained using all the attributes

# %% [markdown]
# Logistic Regression

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression #importing logistic regression
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)  # Predictions from logistic regression
score1 = lr.score(X_test, y_test)
print(f'Number of features used = {len(X_train.columns)}')
print(f'Accuracy in predicting customer satisfaction = {score2}')
# Out:
# Number of features used = 21
# Accuracy in predicting customer satisfaction = 0.8050557620817844

# %% [markdown]
# Predicting customer satisfaction solely based on the feedback

# %%
feedback
# Out:
# ['Seat_comfort',
#  'Departure.Arrival.time_convenient',
#  'Food_drink',
#  'Gate_location',
#  'Inflightwifi_service',
#  'Inflight_entertainment',
#  'Online_support',
#  'Ease_of_Onlinebooking',
#  'Onboard_service',
#  'Leg_room_service',
#  'Baggage_handling',
#  'Checkin_service',
#  'Cleanliness',
#  'Online_boarding']

# %%
#Logistic Regression with only feedback columns
X_train, X_test, y_train, y_test = train_test_split(X.loc[:,feedback], 
                                                    y, 
                                                    random_state = 1, 
                                                    stratify = y)
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
score2 = lr.score(X_test, y_test)

print(f'Number of features used = {len(X_train.columns)}')
print(f'Accuracy of predicting satisfaction based on the feedback = {score2}')
# Out:
# Number of features used = 14
# Accuracy of predicting satisfaction based on the feedback = 0.8050557620817844

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
score3 = dt.score(X_test, y_test)
pred = dt.predict(X_test)
print(f"Decision tree acccuracy score: {score3}")
# Out:
# Decision tree acccuracy score: 0.930185873605948

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
score4 = rf.score(X_test, y_test)
print(f'Random Forest accuracy score = {score4}')
# Out:
# Random Forest accuracy score = 0.9525650557620818

# %% [markdown]
# ### 18. Print feature importance
# - Print feature importance of Random Forest

# %%
#Decision Tree 
pd.Series(dt.feature_importances_, X_train.columns ).sort_values(ascending= False)
# Out:
# Inflight_entertainment               0.386797
# Seat_comfort                         0.180254
# Ease_of_Onlinebooking                0.069682
# CustomerType                         0.049552
# TypeTravel                           0.037601
# Flight_Distance                      0.031657
# Age                                  0.027723
# Class                                0.022538
# Gate_location                        0.021995
# Departure.Arrival.time_convenient    0.020473
# Online_support                       0.020289
# Checkin_service                      0.017956
# ArrivalDelayin_Mins                  0.017617
# Baggage_handling                     0.016031
# Gender                               0.015899
# Leg_room_service                     0.015899
# Cleanliness                          0.014202
# Onboard_service                      0.010907
# Online_boarding                      0.008737
# Inflightwifi_service                 0.007183
# Food_drink                           0.007008
# dtype: float64

# %%
#RandomForest Easy Way
#pd.Series(rf.feature_importances_, X_train.columns).sort_values(ascending= False)
#RandomForest Sweet Way
pd.DataFrame({'Attribute': X_train.columns, 'Importance': rf.feature_importances_}).sort_values('Importance', axis=0, ascending=False)
# Out:
#                             Attribute  Importance
# 5              Inflight_entertainment    0.191730
# 0                        Seat_comfort    0.131393
# 7               Ease_of_Onlinebooking    0.084284
# 6                      Online_support    0.057978
# 8                     Onboard_service    0.047557
# 15                       CustomerType    0.042678
# 18                              Class    0.040203
# 2                          Food_drink    0.039616
# 19                    Flight_Distance    0.039408
# 13                    Online_boarding    0.037103
# 9                    Leg_room_service    0.036127
# 16                                Age    0.033777
# 14                             Gender    0.029451
# 12                        Cleanliness    0.027896
# 11                    Checkin_service    0.027442
# 17                         TypeTravel    0.025838
# 10                   Baggage_handling    0.024888
# 1   Departure.Arrival.time_convenient    0.023113
# 3                       Gate_location    0.020806
# 20                ArrivalDelayin_Mins    0.020148
# 4                Inflightwifi_service    0.018564

# %% [markdown]
# # Model Tuning

# %% [markdown]
# ### 19. Print cross validation score
# - Decision tree model trained using all the attributes
# - Random Forest model trained using all the attributes
# - Fine tuned (using Grid Search or Random Search) Random Forest model
#
# **Display all the scores above with their respective models in a single dataframe**

# %% [markdown]
# Cross Validation Score

# %%
# For Decision Tree dt
from sklearn.model_selection import cross_val_score
score5 = cross_val_score(dt, X, y, cv = 10).mean()
print(f'Cross validation score of Decision tree = {score5}')
# Out:
# Cross validation score of Decision tree = 0.9354436086640113

# %%
# For Random Forest rf
score6 = cross_val_score(rf, X, y, cv = 10).mean()
print(f'Cross validation score of Random forest = {score6}')
# Out:
# Cross validation score of Random forest = 0.953659954621822

# %% [markdown]
# Parameter Tuning Using GridDSearch
#
# Doing it only for RandomForest as the mean CV score is better.

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'bootstrap': [True],
              'max_depth': [10, 20, 30, 40, 50],
              'max_features': ['auto', 'sqrt'],
              'min_samples_leaf': [1, 2, 4, 8],
              'n_estimators': [100]}

clf = GridSearchCV(RandomForestClassifier(), parameters, cv = 5, verbose = 2, n_jobs= 4)
clf.fit(X, y)
clf.best_params_
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:  2.9min finished
# {'bootstrap': True,
#  'max_depth': 40,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'n_estimators': 100}

# %%
rf = RandomForestClassifier(bootstrap= True,
                            max_depth= 40,
                            max_features= 'auto',
                            min_samples_leaf= 1,
                            n_estimators= 100)

score7 = cross_val_score(rf, X, y, cv = 5).mean()
score7
# Out:
# 0.9536599616954217

# %%
data = {'Technique' : ['Logistic Regression', 
                       'LR with only feedback columns', 
                       'Decision tree',
                       'Random forest', 
                       'DT CV',
                       'RF CV',
                       'Tuned RF CV'],
       'Score' : [score1, score2, score3, score4, score5, score6, score7]
       }
result = pd.DataFrame(data)
result
# Out:
#                        Technique     Score
# 0            Logistic Regression  0.835985
# 1  LR with only feedback columns  0.805056
# 2                  Decision tree  0.930186
# 3                  Random forest  0.952565
# 4                          DT CV  0.935444
# 5                          RF CV  0.953660
# 6                    Tuned RF CV  0.953660

# %% [markdown]
# # Pipeline - Automate and Simplify the process

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /opt/anaconda3/lib/python3.7/site-packages (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /opt/anaconda3/lib/python3.7/site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/anaconda3/lib/python3.7/site-packages (from category_encoders) (0.10.1)
# Requirement already satisfied: numpy>=1.14.0 in /opt/anaconda3/lib/python3.7/site-packages (from category_encoders) (1.17.2)
# Requirement already satisfied: pandas>=0.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from category_encoders) (1.1.2)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/lib/python3.7/site-packages (from category_encoders) (0.23.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from patsy>=0.5.1->category_encoders) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.21.1->category_encoders) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.21.1->category_encoders) (2019.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.20.0->category_encoders) (0.13.2)

# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from category_encoders import OrdinalEncoder

numeric_features = ['Age', 'Flight_Distance', 'DepartureDelayin_Mins']
feedback_features = ['Seat_comfort', 'Departure.Arrival.time_convenient', 
                     'Food_drink', 'Gate_location', 'Inflightwifi_service',
                     'Inflight_entertainment', 'Online_support', 
                     'Ease_of_Onlinebooking', 'Onboard_service',
                     'Leg_room_service', 'Baggage_handling', 'Checkin_service',
                     'Cleanliness', 'Online_boarding']
other_cat_cols =  ['Gender', 'CustomerType', 'TypeTravel', 'Class']

#TRANSFORMERS
numeric_transformer = Pipeline( steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

feedback_feature_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='not_captured')),
    ('label_encoder', OrdinalEncoder()),
    ('scaler', StandardScaler())])

other_cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='not_captured')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('feed_col', feedback_feature_transformer, feedback_features),
        ('other_cat_col', other_cat_transformer, other_cat_cols )
    ])

# %%
#Adding into Pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(bootstrap= True,
                                                            max_depth= 30,
                                                            max_features= 'auto',
                                                            min_samples_leaf= 1,
                                                            n_estimators= 100))])

# %%
#Taking the raw data
data = df2.set_index("Id").join(df1.set_index("ID"))

# %%
#Getting X and y
X_pipe = data.drop(['Satisfaction', 'ArrivalDelayin_Mins'], axis = 1)
y_pipe = data['Satisfaction']

# %%
#Data Split
X_trains, X_tests, y_trains, y_tests = train_test_split(X_pipe, y_pipe, stratify = y_pipe)

# %%
#Fitting Pipeline
clf.fit(X_trains, y_trains)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Flight_Distance',
#                                                    'DepartureDelayin_Mins']),
#                                                  ('feed_col',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='not_captured',
#                                                                                  strategy='constant')),
#                                                                   ('label_encoder',
#                                                                    OrdinalEncoder()),
#                                                                   (...
#                                                    'Leg_room_service',
#                                                    'Baggage_handling',
#                                                    'Checkin_service',
#                                                    'Cleanliness',
#                                                    'Online_boarding']),
#                                                  ('other_cat_col',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='not_captured',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Gender', 'CustomerType',
#                                                    'TypeTravel', 'Class'])])),
#                 ('classifier', RandomForestClassifier(max_depth=30))])

# %%
#Getting score
clf.score(X_tests, y_tests)
# Out:
# 0.9475142982842059

# %% [markdown]
# # Conclusion:
#
# - Given some data, we have seen how to perform EDA for that dataset
# - The data that we had was not entirely continuous or categorical. Hence we improvised the analysis to draw insights
# - We used the same old bar-charts but the way we interpreted is unique to this problem
# - Beyond EDA, we have seen how to preprocess data and train Supervised Models with it
# - We finally put all the steps in one place and built a pipeline using the Sklearn's Pipeline function
#
# # Explore:
#
# - You can cluster different segments of customer to get more insights about their behaviours.
# - Create new features and select the best features to improve your model further.
