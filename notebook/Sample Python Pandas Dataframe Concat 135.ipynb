# %%
dir
# Out:
# <function dir>

# %%
pwd
# Out:
# '/Users/pichappan/Documents/SamplePython/input'

# %%
cd ../input
# Out:
# /Users/pichappan/Documents/SamplePython/input

# %%
import pandas as pd

# %%
df1 = pd.read_csv('AAPL.csv')
df1.head()
# Out:
#   Stock      Date        Open        High         Low       Close    Volume
# 0  AAPL  4/1/2020  246.500000  248.720001  239.130005  240.910004  44054600
# 1  AAPL  4/2/2020  240.339996  245.149994  236.899994  244.929993  41483500
# 2  AAPL  4/3/2020  242.800003  245.699997  238.970001  241.410004  32470000
# 3  AAPL  4/6/2020  250.899994  263.109985  249.380005  262.470001  50455100
# 4  AAPL  4/7/2020  270.799988  271.700012  259.000000  259.429993  50721800

# %%
df2 = pd.read_csv('GOOG.csv')
df2.head()
# Out:
#   Stock      Date         Open         High          Low        Close   Volume
# 0  GOOG  4/1/2020  1122.000000  1129.689941  1097.449951  1105.619995  2344200
# 1  GOOG  4/2/2020  1098.260010  1126.859985  1096.400024  1120.839966  1964900
# 2  GOOG  4/3/2020  1119.015015  1123.540039  1079.810059  1097.880005  2313400
# 3  GOOG  4/6/2020  1138.000000  1194.660034  1130.939941  1186.920044  2664700
# 4  GOOG  4/7/2020  1221.000000  1225.000000  1182.229980  1186.510010  2387300

# %%
df3 = pd.read_csv('TSLA.csv')
df3.head()
# Out:
#   Stock      Date        Open        High         Low       Close    Volume
# 0  TSLA  4/1/2020  504.000000  513.950012  475.100006  481.559998  13353200
# 1  TSLA  4/2/2020  481.029999  494.260010  446.399994  454.470001  19858400
# 2  TSLA  4/3/2020  509.500000  515.489990  468.390015  480.010010  22562100
# 3  TSLA  4/6/2020  511.200012  521.000000  497.959991  516.239990  14901800
# 4  TSLA  4/7/2020  545.000000  565.000000  532.340027  545.450012  17919800

# %%
df4 = pd.concat([df1, df2, df3])
df4.dtypes
df4
# Out:
#    Stock       Date        Open        High         Low       Close    Volume
# 0   AAPL   4/1/2020  246.500000  248.720001  239.130005  240.910004  44054600
# 1   AAPL   4/2/2020  240.339996  245.149994  236.899994  244.929993  41483500
# 2   AAPL   4/3/2020  242.800003  245.699997  238.970001  241.410004  32470000
# 3   AAPL   4/6/2020  250.899994  263.109985  249.380005  262.470001  50455100
# 4   AAPL   4/7/2020  270.799988  271.700012  259.000000  259.429993  50721800
# ..   ...        ...         ...         ...         ...         ...       ...
# 16  TSLA  4/24/2020  710.809998  730.729980  698.179993  725.150024  13237600
# 17  TSLA  4/27/2020  737.609985  799.489990  735.000000  798.750000  20681400
# 18  TSLA  4/28/2020  795.640015  805.000000  756.690002  769.119995  15222000
# 19  TSLA  4/29/2020  790.169983  803.200012  783.159973  800.510010  16216000
# 20  TSLA  4/30/2020  855.190002  869.820007  763.500000  781.880005  28471900
#
# [63 rows x 7 columns]

# %%
df5 = pd.concat([df1, df2, df3], keys=['Apple','Google','Tesla'])
df5.columns
df5
# Out:
#          Stock       Date        Open        High         Low       Close  \
# Apple 0   AAPL   4/1/2020  246.500000  248.720001  239.130005  240.910004
#       1   AAPL   4/2/2020  240.339996  245.149994  236.899994  244.929993
#       2   AAPL   4/3/2020  242.800003  245.699997  238.970001  241.410004
#       3   AAPL   4/6/2020  250.899994  263.109985  249.380005  262.470001
#       4   AAPL   4/7/2020  270.799988  271.700012  259.000000  259.429993
# ...        ...        ...         ...         ...         ...         ...
# Tesla 16  TSLA  4/24/2020  710.809998  730.729980  698.179993  725.150024
#       17  TSLA  4/27/2020  737.609985  799.489990  735.000000  798.750000
#       18  TSLA  4/28/2020  795.640015  805.000000  756.690002  769.119995
#       19  TSLA  4/29/2020  790.169983  803.200012  783.159973  800.510010
#       20  TSLA  4/30/2020  855.190002  869.820007  763.500000  781.880005
#
#             Volume
# Apple 0   44054600
#       1   41483500
# ...

# %%
# get Dataframe for index Apple
df5.loc['Apple']
# Out:
#    Stock       Date        Open        High         Low       Close    Volume
# 0   AAPL   4/1/2020  246.500000  248.720001  239.130005  240.910004  44054600
# 1   AAPL   4/2/2020  240.339996  245.149994  236.899994  244.929993  41483500
# 2   AAPL   4/3/2020  242.800003  245.699997  238.970001  241.410004  32470000
# 3   AAPL   4/6/2020  250.899994  263.109985  249.380005  262.470001  50455100
# 4   AAPL   4/7/2020  270.799988  271.700012  259.000000  259.429993  50721800
# 5   AAPL   4/8/2020  262.739990  267.369995  261.230011  266.070007  42223800
# 6   AAPL   4/9/2020  268.700012  270.070007  264.700012  267.989990  40529100
# 7   AAPL  4/13/2020  268.309998  273.700012  265.829987  273.250000  32755700
# 8   AAPL  4/14/2020  280.000000  288.250000  278.049988  287.049988  48748700
# 9   AAPL  4/15/2020  282.399994  286.329987  280.630005  284.429993  32788600
# 10  AAPL  4/16/2020  287.380005  288.200012  282.350006  286.690002  39281300
# ...

# %%
pd.concat([df1, df2, df3], axis=1) # data line up by index column, so make sure index do match with data order
# Out:
#     Stock       Date        Open        High         Low       Close  \
# 0    AAPL   4/1/2020  246.500000  248.720001  239.130005  240.910004
# 1    AAPL   4/2/2020  240.339996  245.149994  236.899994  244.929993
# 2    AAPL   4/3/2020  242.800003  245.699997  238.970001  241.410004
# 3    AAPL   4/6/2020  250.899994  263.109985  249.380005  262.470001
# 4    AAPL   4/7/2020  270.799988  271.700012  259.000000  259.429993
# 5    AAPL   4/8/2020  262.739990  267.369995  261.230011  266.070007
# 6    AAPL   4/9/2020  268.700012  270.070007  264.700012  267.989990
# 7    AAPL  4/13/2020  268.309998  273.700012  265.829987  273.250000
# 8    AAPL  4/14/2020  280.000000  288.250000  278.049988  287.049988
# 9    AAPL  4/15/2020  282.399994  286.329987  280.630005  284.429993
# 10   AAPL  4/16/2020  287.380005  288.200012  282.350006  286.690002
# 11   AAPL  4/17/2020  284.690002  286.950012  276.859985  282.799988
# 12   AAPL  4/20/2020  277.950012  281.679993  276.850006  276.929993
# ...

# %%
df6 = pd.concat([df1, df2, df3], ignore_index=True)
df6.columns
df6
