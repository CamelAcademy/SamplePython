# %%
import pandas as pd

# %%
df0 = pd.read_csv('app-category-rating-reviews-size.csv')
df0.shape
# Out:
# (10841, 13)

# %%
rows, columns = df0.shape

# %%
df0.head() # to print all df or df[:]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df0[2:5] #row filter - df[a:b] to print rows numbers from a to b-1 but not b
# Out:
#                                                  App        Category  Rating  \
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                     Genres    Last Updated         Current Ver   Android Ver
# 2             Art & Design  August 1, 2018               1.2.4  4.0.3 and up
# 3             Art & Design    June 8, 2018  Varies with device    4.2 and up
# 4  Art & Design;Creativity   June 20, 2018                 1.1    4.4 and up

# %%
df0.columns # to print column header
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df0.App # to print a column - 1st way
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
df0['Category'] # to print a column - 2st way
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
df0[['Category', 'Rating', 'Reviews', 'Size']] # to display multiple columns
# Out:
#                   Category  Rating Reviews                Size
# 0           ART_AND_DESIGN     4.1     159                 19M
# 1           ART_AND_DESIGN     3.9     967                 14M
# 2           ART_AND_DESIGN     4.7   87510                8.7M
# 3           ART_AND_DESIGN     4.5  215644                 25M
# 4           ART_AND_DESIGN     4.3     967                2.8M
# ...                    ...     ...     ...                 ...
# 10836               FAMILY     4.5      38                 53M
# 10837               FAMILY     5.0       4                3.6M
# 10838              MEDICAL     NaN       3                9.5M
# 10839  BOOKS_AND_REFERENCE     4.5     114  Varies with device
# 10840            LIFESTYLE     4.5  398307                 19M
#
# [10841 rows x 4 columns]

# %%
type(df0.Category) # Columns in Pandas are of type Series
# Out:
# pandas.core.series.Series

# %%
df0.Rating.max() # the maximum value of Rating column by .notation
# Out:
# 19.0

# %%
df0['Category'].max() # the maximum value of column, work for non-numeric columns too
# Out:
# 'WEATHER'

# %%
df0.Rating.mean() # df0['Rating'].mean()
# Out:
# 4.193338315362448

# %%
df0.Rating.std()
# Out:
# 0.5374313031477594

# %%
df0.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 592.9+ KB

# %%
df0[df0.Rating>4.9] # numeric columns
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
df0[df0.Category == 'GAME'] # non-numeric column
# Out:
#                                 App Category  Rating   Reviews Size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              Installs  Type Price Content Rating  \
# 1653     100,000,000+  Free     0   Everyone 10+
# ...

# %%
df0['App'][df0.Category =='GAME'] # Display App column with filter on Category column
# Out:
# 1653                           ROBLOX
# 1654                   Subway Surfers
# 1655                 Candy Crush Saga
# 1656                        Solitaire
# 1657                   Bubble Shooter
#                      ...
# 10791               Winter Wonderland
# 10792          Soccer Clubs Logo Quiz
# 10793                       Sid Story
# 10803    Fatal Raid - No.1 Mobile FPS
# 10804                    Poker Pro.Fr
# Name: App, Length: 1144, dtype: object

# %%
df0[['App','Category']][df0.Category =='GAME'] # Multiple columns with a constrain
# Out:
#                                 App Category
# 1653                         ROBLOX     GAME
# 1654                 Subway Surfers     GAME
# 1655               Candy Crush Saga     GAME
# 1656                      Solitaire     GAME
# 1657                 Bubble Shooter     GAME
# ...                             ...      ...
# 10791             Winter Wonderland     GAME
# 10792        Soccer Clubs Logo Quiz     GAME
# 10793                     Sid Story     GAME
# 10803  Fatal Raid - No.1 Mobile FPS     GAME
# 10804                  Poker Pro.Fr     GAME
#
# [1144 rows x 2 columns]

# %%
df0.index # index start with 0 and stop 1 after
# Out:
# RangeIndex(start=0, stop=10841, step=1)

# %%
df0.set_index('Category', inplace=True) # index not required to be unique

# %%
df0.loc['MEDICAL'] # access using labels
# Out:
#                                  App  Rating Reviews                Size  \
# Category
# MEDICAL   Monash Uni Low FODMAP Diet     4.2    1135                 12M
# MEDICAL           iBP Blood Pressure     4.4     578                704k
# MEDICAL                    Pedi STAT     4.6     129                2.9M
# MEDICAL                 ASCCP Mobile     4.5      63                 25M
# MEDICAL       Journal Club: Medicine     4.8     216  Varies with device
# ...                              ...     ...     ...                 ...
# MEDICAL                  FP Notebook     4.5     410                 60M
# MEDICAL                         AAFP     3.8      63                 24M
# MEDICAL              SnakeBite911 FR     NaN       1                 42M
# MEDICAL                    Cardio-FR     NaN      67                 82M
# MEDICAL       Parkinson Exercices FR     NaN       3                9.5M
#
#           Installs  Type  Price Content Rating   Genres       Last Updated  \
# ...

# %%
df0.reset_index(inplace=True)

# %%
df0.set_index('Rating', inplace=True) # index not required to be unique

# %%
df0.loc[19] #Single label. Note this returns the row as a Series. Filter select just 1 row.
# Out:
# Category                                              1.9
# App               Life Made WI-Fi Touchscreen Photo Frame
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 19.0, dtype: object

# %%
df0.loc[[3.9,19]] #List of labels. Note using [[]] returns a DataFrame.
# Out:
#                  Category                                                App  \
# Rating
# 3.9        ART_AND_DESIGN                                Coloring book moana
# 3.9        ART_AND_DESIGN                              Pencil Sketch Drawing
# 3.9     AUTO_AND_VEHICLES                           American Muscle Car Race
# 3.9     AUTO_AND_VEHICLES  REG - Check the regnumber, find information ab...
# 3.9     AUTO_AND_VEHICLES                                  Check Vehicle Tax
# ...                   ...                                                ...
# 3.9               FINANCE                                         BankNordik
# 3.9                FAMILY                     FeaturePoints: Free Gift Cards
# 3.9          PRODUCTIVITY                                           FQ METER
# 3.9                  GAME                             BEBONCOOL GAMEPAD V1.0
# 19.0                  1.9            Life Made WI-Fi Touchscreen Photo Frame
#
# ...
