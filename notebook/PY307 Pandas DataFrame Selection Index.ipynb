# %%
import pandas as pd
import random
 
# Read CSV would read the CSV file over the internet too.
df0 = pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')
rows, columns = df0.shape
print('Total # of rows: {} and columns: {} in DataFrame df0'.format(rows, df0.shape[1]))

# set a numeric id for use as an index for examples.
df0['rand'] = [random.randint(10,99) for x in range(df0.shape[0])]
 
df0
# Out:
# Total # of rows: 500 and columns: 11 in DataFrame df0
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# ...

# %%
# Single Row selection from DataFrame using iloc. Note output data type is Series.
df0.iloc[0] # first row of data frame (Aleshia Tomkiewicz)
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# rand                                              36
# Name: 0, dtype: object

# %%
# Single Row selection from DataFrame using iloc. Note output data type is Series.
df0.iloc[-1] # last row of DataFrame (Mi Richan)
# Out:
# first_name                                               Mi
# last_name                                            Richan
# company_name                 Nelson Wright Haworth Golf Crs
# address                                     6 Norwood Grove
# city                                      Tanworth-in-Arden
# county                                         Warwickshire
# postal                                              B94 5RZ
# phone1                                         01451-785624
# phone2                                         01202-738406
# email                                        mi@hotmail.com
# web             http://www.nelsonwrighthaworthgolfcrs.co.uk
# rand                                                     50
# Name: 499, dtype: object

# %%
# Single Row selection from DataFrame using iloc. Note output data type is Series.
df0.iloc[-2] # second last row of DataFrame (Celestina Keeny)
# Out:
# first_name                                   Celestina
# last_name                                        Keeny
# company_name                  Bfg Federal Credit Union
# address                                    9 Milton St
# city                                  Consett North ED
# county                                   County Durham
# postal                                         DH8 5LP
# phone1                                    01877-379681
# phone2                                    01600-463475
# email                        celestina_keeny@gmail.com
# web             http://www.bfgfederalcreditunion.co.uk
# rand                                                80
# Name: 498, dtype: object

# %%
# Single Column selection from DataFrame using iloc. Note output data type is Series.
# first column first_name of DataFrame
df0.iloc[:,0]
# Out:
# 0        Aleshia
# 1           Evan
# 2         France
# 3        Ulysses
# 4         Tyisha
#          ...
# 495        Avery
# 496         Reid
# 497    Charlette
# 498    Celestina
# 499           Mi
# Name: first_name, Length: 500, dtype: object

# %%
# Single Column selection from DataFrame using iloc. Note output data type is Series.
# last column rand of DataFrame
df0.iloc[:,-1]
# Out:
# 0      36
# 1      88
# 2      55
# 3      25
# 4      35
#        ..
# 495    48
# 496    15
# 497    24
# 498    80
# 499    50
# Name: rand, Length: 500, dtype: int64

# %%
# Double Column selection from DataFrame using iloc. Note output data type is DataFrame.
# first & second column first_name & last_name of DataFrame
df0.iloc[:,[0,1]]
# Out:
#     first_name   last_name
# 0      Aleshia  Tomkiewicz
# 1         Evan   Zigomalas
# 2       France     Andrade
# 3      Ulysses   Mcwalters
# 4       Tyisha      Veness
# ..         ...         ...
# 495      Avery        Veit
# 496       Reid     Euresti
# 497  Charlette    Brenning
# 498  Celestina       Keeny
# 499         Mi      Richan
#
# [500 rows x 2 columns]

# %%
# Double Column selection from DataFrame using iloc. Note output data type is DataFrame.
# first & second column but not the third column of DataFrame
df0.iloc[:, 0:2]
# Out:
#     first_name   last_name
# 0      Aleshia  Tomkiewicz
# 1         Evan   Zigomalas
# 2       France     Andrade
# 3      Ulysses   Mcwalters
# 4       Tyisha      Veness
# ..         ...         ...
# 495      Avery        Veit
# 496       Reid     Euresti
# 497  Charlette    Brenning
# 498  Celestina       Keeny
# 499         Mi      Richan
#
# [500 rows x 2 columns]

# %%
# Selection of multiple rows and all columns with iloc. Note output data type is DataFrame.
df0.iloc[0:5]
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
# Selection of multiple rows (1st, 6th, 11th & 16th) and columns(1st, 2nd & 5th) with iloc
df0.iloc[[0,5,10,15], [0,1,4]] # Note output data type is DataFrame.
# Out:
#    first_name   last_name               city
# 0     Aleshia  Tomkiewicz  St. Stephens Ward
# 5        Eric       Rampy         Desborough
# 10   Fernanda      Writer         Wilmington
# 15    Michell   Throssell          Carbrooke

# %%
# Selection of multiple rows(1st to 5th but not 6th) and columns(1st to 3rd but not 4th) with iloc
df0.iloc[0:5, 0:3] # rows(starting from 0, 5 of them) columns (starting from 0, 3 of them)
# Out:
#   first_name   last_name             company_name
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc
# 1       Evan   Zigomalas       Cap Gemini America
# 2     France     Andrade      Elliott, John W Esq
# 3    Ulysses   Mcwalters           Mcmahan, Ben L
# 4     Tyisha      Veness           Champagne Room

# %%
# loc Access a group of rows and columns by label(s) or a boolean array.
# 1. Selecting rows by label/index.
# 2. Selecting rows with a boolean / conditional lookup

df0.set_index("email", inplace=True)
df0.head()
# Out:
#                            first_name   last_name             company_name  \
# email
# atomkiewicz@hotmail.com       Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc
# evan.zigomalas@gmail.com         Evan   Zigomalas       Cap Gemini America
# france.andrade@hotmail.com     France     Andrade      Elliott, John W Esq
# ulysses@hotmail.com           Ulysses   Mcwalters           Mcmahan, Ben L
# tyisha.veness@hotmail.com      Tyisha      Veness           Champagne Room
#
#                                       address                            city  \
# email
# atomkiewicz@hotmail.com          14 Taylor St               St. Stephens Ward
# evan.zigomalas@gmail.com          5 Binney St                      Abbey Ward
# france.andrade@hotmail.com       8 Moor Place  East Southbourne and Tuckton W
# ulysses@hotmail.com             505 Exeter Rd              Hawerby cum Beesby
# tyisha.veness@hotmail.com   5396 Forth Street      Greets Green and Lyng Ward
#
# ...

# %%
df0.loc['france.andrade@hotmail.com']
# Out:
# first_name                                France
# last_name                                Andrade
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# web             http://www.elliottjohnwesq.co.uk
# rand                                          55
# Name: france.andrade@hotmail.com, dtype: object

# %%
df0.loc[['france.andrade@hotmail.com','tyisha.veness@hotmail.com']]
# Out:
#                            first_name last_name         company_name  \
# email
# france.andrade@hotmail.com     France   Andrade  Elliott, John W Esq
# tyisha.veness@hotmail.com      Tyisha    Veness       Champagne Room
#
#                                       address                            city  \
# email
# france.andrade@hotmail.com       8 Moor Place  East Southbourne and Tuckton W
# tyisha.veness@hotmail.com   5396 Forth Street      Greets Green and Lyng Ward
#
#                                    county   postal        phone1  \
# email
# france.andrade@hotmail.com    Bournemouth  BH6 3BE  01347-368222
# tyisha.veness@hotmail.com   West Midlands  B70 9DT  01547-429341
#
#                                   phone2                               web  \
# email
# france.andrade@hotmail.com  01935-821636  http://www.elliottjohnwesq.co.uk
# tyisha.veness@hotmail.com   01290-367248    http://www.champagneroom.co.uk
#
#                             rand
# email
# ...

# %%
df0.loc[['france.andrade@hotmail.com','tyisha.veness@hotmail.com'],['first_name','company_name','city']]
# Out:
#                            first_name         company_name  \
# email
# france.andrade@hotmail.com     France  Elliott, John W Esq
# tyisha.veness@hotmail.com      Tyisha       Champagne Room
#
#                                                       city
# email
# france.andrade@hotmail.com  East Southbourne and Tuckton W
# tyisha.veness@hotmail.com       Greets Green and Lyng Ward

# %%
# Change the index to be based on the 'rand' column. It is not required to be unique column!
df0.reset_index(inplace=True)
df0.set_index('rand', inplace=True)

# %%
# select the row with 'rand' = 88
df0.loc[88]
# Out:
#                          email first_name  last_name          company_name  \
# rand
# 88    evan.zigomalas@gmail.com       Evan  Zigomalas    Cap Gemini America
# 88       fernanda@writer.co.uk   Fernanda     Writer  K & R Associates Inc
# 88          paschoff@yahoo.com      Pedro    Aschoff     Charlotte Chamber
# 88         stefany@hotmail.com    Stefany     Ferenz    L & L Sales Co Inc
# 88    eleni_vanscoik@gmail.com      Eleni   Vanscoik   Simpson, Fred B Esq
# 88    jacki.sterback@gmail.com      Jacki   Sterback   Praver, David L Esq
# 88           pansy@kopan.co.uk      Pansy      Kopan             Oncor Inc
#
#                  address                            city           county  \
# rand
# 88           5 Binney St                      Abbey Ward  Buckinghamshire
# 88    620 Northampton St                      Wilmington             Kent
# 88           135 Opie St                Howard Town Ward       Derbyshire
# ...

# %%
df0.reset_index(inplace=True)
df0.set_index('first_name', inplace=True)
df0.tail()
# Out:
#             rand                      email last_name  \
# first_name
# Avery         48           avery@veit.co.uk      Veit
# Reid          15     reuresti@euresti.co.uk   Euresti
# Charlette     24   cbrenning@brenning.co.uk  Brenning
# Celestina     80  celestina_keeny@gmail.com     Keeny
# Mi            50             mi@hotmail.com    Richan
#
#                               company_name             address  \
# first_name
# Avery           Plaza Gourmet Delicatessen  9166 Devon St #905
# Reid                  Fitzgerald, Edward J        70 Foster St
# Charlette               Furey & Associates     714 Fonthill Rd
# Celestina         Bfg Federal Credit Union         9 Milton St
# Mi          Nelson Wright Haworth Golf Crs     6 Norwood Grove
#
#                                       city           county    postal  \
# first_name
# Avery       Knightsbridge and Belgravia Wa   Greater London  SW1W 8JY
# Reid              Inverness Ness-Side Ward         Highland   IV2 6WT
# ...

# %%
# Select rows with index values Aleshia, Evan and Ulysses, with all columns between 'city' and 'web'
df0.loc[['Aleshia', 'Ulysses','Evan'], 'city':'web']
# Out:
#                           city           county    postal        phone1  \
# first_name
# Aleshia      St. Stephens Ward             Kent   CT2 7PP  01835-703597
# Ulysses     Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# Evan                Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
#
#                   phone2                                   web
# first_name
# Aleshia     01944-369967  http://www.alandrosenburgcpapc.co.uk
# Ulysses     01302-601380          http://www.mcmahanbenl.co.uk
# Evan        01714-737668     http://www.capgeminiamerica.co.uk

# %%
# Select rows, with first name in between 2 and columns company_name, city and web.
df0.loc['Aleshia':'Ulysses', ['company_name', 'city', 'web']]
# Out:
#                        company_name                            city  \
# first_name
# Aleshia     Alan D Rosenburg Cpa Pc               St. Stephens Ward
# Evan             Cap Gemini America                      Abbey Ward
# France          Elliott, John W Esq  East Southbourne and Tuckton W
# Ulysses              Mcmahan, Ben L              Hawerby cum Beesby
#
#                                              web
# first_name
# Aleshia     http://www.alandrosenburgcpapc.co.uk
# Evan           http://www.capgeminiamerica.co.uk
# France          http://www.elliottjohnwesq.co.uk
# Ulysses             http://www.mcmahanbenl.co.uk

# %%
# Select rows & columns with between 2 values.
df0.loc['Aleshia':'France', 'city':'web']
# Out:
#                                       city           county    postal  \
# first_name
# Aleshia                  St. Stephens Ward             Kent   CT2 7PP
# Evan                            Abbey Ward  Buckinghamshire  HP11 2AX
# France      East Southbourne and Tuckton W      Bournemouth   BH6 3BE
#
#                   phone1        phone2                                   web
# first_name
# Aleshia     01835-703597  01944-369967  http://www.alandrosenburgcpapc.co.uk
# Evan        01937-864715  01714-737668     http://www.capgeminiamerica.co.uk
# France      01347-368222  01935-821636      http://www.elliottjohnwesq.co.uk

# %%
df0.loc[['Tyisha','Charlette','Mi'],['last_name','county']]
# Out:
#            last_name           county
# first_name
# Tyisha        Veness    West Midlands
# Charlette   Brenning  South Yorkshire
# Mi            Richan     Warwickshire

# %%
# Boolean / Logical indexing using loc
df0.loc[df0['last_name']=='Veness', ['company_name','county']]
# Out:
#               company_name         county
# first_name
# Tyisha      Champagne Room  West Midlands

# %%
# Returns a Series
df0.loc[df0['city']=='Abbey Ward', 'county']
# Out:
# first_name
# Evan    Buckinghamshire
# Name: county, dtype: object

# %%
# Returns a DataFrame as input is a list
df0.loc[df0['city']=='Abbey Ward', ['county']]
# Out:
#                      county
# first_name
# Evan        Buckinghamshire

# %%
# Select rows with email id ulysses@hotmail.com and all columns between 'email' and 'city'
df0.loc[df0['email'] == 'ulysses@hotmail.com', 'email':'city']
# Out:
#                           email  last_name    company_name        address  \
# first_name
# Ulysses     ulysses@hotmail.com  Mcwalters  Mcmahan, Ben L  505 Exeter Rd
#
#                           city
# first_name
# Ulysses     Hawerby cum Beesby

# %%
# Select rows where the email column ends with 'hotmail.com' and include all columns
df0.loc[df0['email'].str.endswith("hotmail.com")]
# Out:
#             rand                       email   last_name  \
# first_name
# Aleshia       36     atomkiewicz@hotmail.com  Tomkiewicz
# France        55  france.andrade@hotmail.com     Andrade
# Ulysses       25         ulysses@hotmail.com   Mcwalters
# Tyisha        35   tyisha.veness@hotmail.com      Veness
# Marg          76            marg@hotmail.com    Grasmick
# ...          ...                         ...         ...
# Sophia        91  sophia.gaucher@hotmail.com     Gaucher
# Rosita        89      rausdemore@hotmail.com   Ausdemore
# Huey          77        hstancil@hotmail.com     Stancil
# Elbert        16          elbert@hotmail.com     Fiorino
# Mi            50              mi@hotmail.com      Richan
#
#                               company_name                 address  \
# first_name
# Aleshia            Alan D Rosenburg Cpa Pc            14 Taylor St
# France                 Elliott, John W Esq            8 Moor Place
# ...

# %%
# Select rows with last_name equal to isin values
df0.loc[df0['last_name'].isin(['Veness', 'Richan', 'Eric'])]
# Out:
#             rand                      email last_name  \
# first_name
# Tyisha        35  tyisha.veness@hotmail.com    Veness
# Mi            50             mi@hotmail.com    Richan
#
#                               company_name            address  \
# first_name
# Tyisha                      Champagne Room  5396 Forth Street
# Mi          Nelson Wright Haworth Golf Crs    6 Norwood Grove
#
#                                   city         county   postal        phone1  \
# first_name
# Tyisha      Greets Green and Lyng Ward  West Midlands  B70 9DT  01547-429341
# Mi                   Tanworth-in-Arden   Warwickshire  B94 5RZ  01451-785624
#
#                   phone2                                          web
# first_name
# Tyisha      01290-367248               http://www.champagneroom.co.uk
# Mi          01202-738406  http://www.nelsonwrighthaworthgolfcrs.co.uk

# %%
# Select rows with last name Veness AND email id ends with hotmail.com
df0.loc[df0['email'].str.endswith("hotmail.com") & (df0['last_name'] == 'Veness')]
# Out:
#             rand                      email last_name    company_name  \
# first_name
# Tyisha        35  tyisha.veness@hotmail.com    Veness  Champagne Room
#
#                       address                        city         county  \
# first_name
# Tyisha      5396 Forth Street  Greets Green and Lyng Ward  West Midlands
#
#              postal        phone1        phone2  \
# first_name
# Tyisha      B70 9DT  01547-429341  01290-367248
#
#                                        web
# first_name
# Tyisha      http://www.champagneroom.co.uk

# %%
# select rows with ununique rand column between 100 and 200, and just return 'postal' and 'web' columns
df0.loc[(df0['rand'] >= 24) & (df0['rand'] <= 25), ['postal', 'web','rand']]
# Out:
#               postal                                           web  rand
# first_name
# Ulysses     DN36 5RP                  http://www.mcmahanbenl.co.uk    25
# Craig       SW15 2RP                http://www.berryjohnmesq.co.uk    24
# Maybelle    CF42 6PL                 http://www.gavinleewesq.co.uk    25
# Lindsay     CW10 9GB          http://www.lutzchristophertesq.co.uk    25
# Elroy       CA17 4RZ                http://www.jonsongeodesq.co.uk    25
# Wei         ST21 6GA               http://www.victorycoating.co.uk    25
# Jordan       ME2 2NJ          http://www.shirleysprintshoppe.co.uk    24
# Adolph       SR5 5PT      http://www.moorheadbridgetkleinesq.co.uk    24
# Lemuel       WS5 4SU   http://www.computersecuritycnslntsinc.co.uk    25
# Jacob       CF40 2JJ             http://www.accautomationinc.co.uk    24
# Dino        GU31 5JN       http://www.containerdecoratinginc.co.uk    25
# Celia       KT22 8AP    http://www.bridgervalleygeneralstore.co.uk    24
# ...

# %%
# Inner lambda function will returns True/False value for each row.
# Then select the rows where the company name is made of 4 words.
df0.loc[df0['company_name'].apply(lambda x: len(x.split(' ')) == 4)]
# Out:
#              rand                         email  last_name  \
# first_name
# France         55    france.andrade@hotmail.com    Andrade
# Eric           80            erampy@rampy.co.uk      Rampy
# Charlesetta    78     charlesetta_erm@gmail.com        Erm
# Michell        95    mthrossell@throssell.co.uk  Throssell
# Edgar          44         edgar.kanne@yahoo.com      Kanne
# ...           ...                           ...        ...
# Ahmad          87       ahmad.alsaqri@yahoo.com    Alsaqri
# Jacquelyne     80  jacquelyne_reibman@yahoo.com    Reibman
# Isabelle       85       isabelle.kono@yahoo.com       Kono
# Elbert         16            elbert@hotmail.com    Fiorino
# Celestina      80     celestina_keeny@gmail.com      Keeny
#
#                              company_name                 address  \
# first_name
# France                Elliott, John W Esq            8 Moor Place
# Eric              Thompson, Michael C Esq            9472 Lind St
# ...
