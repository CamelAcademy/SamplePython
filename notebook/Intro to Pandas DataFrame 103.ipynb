# %%
import pandas as pd

# %%
df_app = pd.read_csv('app-category-rating-reviews-size.csv')

# %%
df_app.shape
# Out:
# (10841, 13)

# %%
rows, columns = df_app.shape

# %%
df_app.head() # to print all df or df[:]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_app[2:5] # row filter - df[a:b] to prints rows numbers from a to b-1 but not b
# Out:
#                                                  App        Category  Rating  \
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                     Genres    Last Updated         Current Ver   Android Ver
# 2             Art & Design  August 1, 2018               1.2.4  4.0.3 and up
# 3             Art & Design    June 8, 2018  Varies with device    4.2 and up
# 4  Art & Design;Creativity   June 20, 2018                 1.1    4.4 and up

# %%
df_app.columns # to print column header
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_app.App # to print columns 1st way
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
df_app['Category'] # to print columns 2nd way
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
df_app[['App', 'Category', 'Rating', 'Reviews', 'Size']] # to display multiple columns
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
type(df_app.Category) # Columns in Pandas are of type Series
# Out:
# pandas.core.series.Series

# %%
df_app.Rating.min() # The min value of Rating column by . notation
# Out:
# 1.0

# %%
df_app['Category'].max() # The max value of Category column, which is non numeric column using []
# Out:
# 'WEATHER'

# %%
df_app['Rating'].mean()
# Out:
# 4.193338315362448

# %%
df_app['Rating'].std()
# Out:
# 0.5374313031477594

# %%
df_app.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df_app[df_app.Rating > 4.9]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
df_app[df_app.Category == 'GAME']
# Out:
#                                 App Category  Rating   Reviews Size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              Installs  Type Price Content Rating  \
# 1653     100,000,000+  Free     0   Everyone 10+
# ...

# %%
df_app['App'][df_app.Category == 'GAME']
# Out:
# 1653                           ROBLOX
# 1654                   Subway Surfers
# 1655                 Candy Crush Saga
# 1656                        Solitaire
# 1657                   Bubble Shooter
#                      ...
# 10791               Winter Wonderland
# 10792          Soccer Clubs Logo Quiz
# 10793                       Sid Story
# 10803    Fatal Raid - No.1 Mobile FPS
# 10804                    Poker Pro.Fr
# Name: App, Length: 1144, dtype: object

# %%
df_app[['App','Category']][df_app.Category == 'GAME'] # multiple columns with in []
# Out:
#                                 App Category
# 1653                         ROBLOX     GAME
# 1654                 Subway Surfers     GAME
# 1655               Candy Crush Saga     GAME
# 1656                      Solitaire     GAME
# 1657                 Bubble Shooter     GAME
# ...                             ...      ...
# 10791             Winter Wonderland     GAME
# 10792        Soccer Clubs Logo Quiz     GAME
# 10793                     Sid Story     GAME
# 10803  Fatal Raid - No.1 Mobile FPS     GAME
# 10804                  Poker Pro.Fr     GAME
#
# [1144 rows x 2 columns]

# %%
df_app.shape
# Out:
# (10841, 13)

# %%
df_app.index # index start with 0 and end 1 after
# Out:
# RangeIndex(start=0, stop=10841, step=1)

# %%
df_app.set_index('Category',inplace=True) # index not required to be unique

# %%
df_app
# Out:
#                                                                    App  \
# Category
# ART_AND_DESIGN          Photo Editor & Candy Camera & Grid & ScrapBook
# ART_AND_DESIGN                                     Coloring book moana
# ART_AND_DESIGN       U Launcher Lite – FREE Live Cool Themes, Hide ...
# ART_AND_DESIGN                                   Sketch - Draw & Paint
# ART_AND_DESIGN                   Pixel Draw - Number Art Coloring Book
# ...                                                                ...
# FAMILY                                                Sya9a Maroc - FR
# FAMILY                                Fr. Mike Schmitz Audio Teachings
# MEDICAL                                         Parkinson Exercices FR
# BOOKS_AND_REFERENCE                      The SCP Foundation DB fr nn5n
# LIFESTYLE                iHoroscope - 2018 Daily Horoscope & Astrology
#
#                      Rating Reviews                Size     Installs  Type  \
# Category
# ...

# %%
df_app.loc['MEDICAL'] # filter by new index
# Out:
#                                  App  Rating Reviews                Size  \
# Category
# MEDICAL   Monash Uni Low FODMAP Diet     4.2    1135                 12M
# MEDICAL           iBP Blood Pressure     4.4     578                704k
# MEDICAL                    Pedi STAT     4.6     129                2.9M
# MEDICAL                 ASCCP Mobile     4.5      63                 25M
# MEDICAL       Journal Club: Medicine     4.8     216  Varies with device
# ...                              ...     ...     ...                 ...
# MEDICAL                  FP Notebook     4.5     410                 60M
# MEDICAL                         AAFP     3.8      63                 24M
# MEDICAL              SnakeBite911 FR     NaN       1                 42M
# MEDICAL                    Cardio-FR     NaN      67                 82M
# MEDICAL       Parkinson Exercices FR     NaN       3                9.5M
#
#           Installs  Type  Price Content Rating   Genres       Last Updated  \
# ...

# %%
df_app.reset_index(inplace=True)

# %%
df_app.set_index('Rating',inplace=True) # index not required to be unique

# %%
df_app.loc[19] # filter by new index which select just 1 rows
# Out:
# Category                                              1.9
# App               Life Made WI-Fi Touchscreen Photo Frame
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 19.0, dtype: object
